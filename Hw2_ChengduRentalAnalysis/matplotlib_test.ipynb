# %%
import matplotlib
print(matplotlib.get_data_path() + '/fonts/ttf')
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
import matplotlib
print(matplotlib.get_cachedir())
# Out:
# /Users/kaihaverz/.matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置字体为 SimHei
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用黑体显示中文
plt.rcParams['axes.unicode_minus'] = False    # 解决负号显示问题


plt.plot([1, 2, 3], [2, 3, 4])
plt.title("测试能不能显示中文")
plt.show()
